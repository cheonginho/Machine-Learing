# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file_data   = "mnist_test.csv"
handle_file = open(file_data, "r")
data        = handle_file.readlines()
handle_file.close()

size_row    = 28    # height of the image
size_col    = 28    # width of the image

num_image   = len(data)
count       = 0     # count for the number of images

#
start = 1
end = 10000
# make a matrix each column of which represents an images in a vector form 
#
###########################

temp_train=np.array(pd.read_csv(file_data)[start-1:end].values,dtype='uint8')


list_image  = np.empty((size_row * size_col, num_image), dtype=float)
list_label  = np.empty(num_image, dtype=int)

for line in data:

    line_data   = line.split(',')
    label       = line_data[0]
    im_vector   = np.asfarray(line_data[1:])

    list_label[count]       = label
    list_image[:, count]    = im_vector    

    count += 1

# 
# plot first 100 images out of 10,000 with their labels
# 
f1 = plt.figure(1)

for i in range(100):

    label       = list_label[i]
    im_vector   = list_image[:, i]
    im_matrix   = im_vector.reshape((size_row, size_col))

    plt.subplot(10, 10, i+1)
    plt.title(label)
    plt.imshow(im_matrix, cmap='Greys', interpolation='None')

    frame   = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)

plt.show()
# Out:
# (9999, 785)

# %% [markdown]
# ## Plot the average image

# %%
fig=plt.figure(figsize=(10,4))
for i in range(10):
    #train_ave=np.mean(train[np.where(temp_train[:,0]==i)],axis=0)
    train_ave=np.mean(temp_train[:,1:][np.where(temp_train[:,0]==i)],axis=0)
    #train_ave=np.mean(temp_train[:,1:][temp_train[:,0]==i],axis=0)
    ax=fig.add_subplot(2,5,i+1)
    ax.set_axis_off
    a=np.copy(train_ave)
    a=np.reshape(a,(28,28))
    plt.title(i)
    ax.imshow(a.reshape((28,28)), cmap='gray', interpolation='None', clim=(0,255))

# %% [markdown]
# ## Present the output of the neural network with random weights

# %%
def sigmoid(z):
    return 1 / 1 + np.exp(-z)

# %%
np.random.seed(777)
theta = np.random.rand(784)
theta
# Out:
# array([0.15266373, 0.30235661, 0.06203641, 0.45986034, 0.83525338,
#        0.92699705, 0.72698898, 0.76849622, 0.26920507, 0.64402929,
#        0.09337326, 0.07968589, 0.58961375, 0.34334054, 0.98887615,
#        0.62647321, 0.68177928, 0.55225681, 0.26886006, 0.37325939,
#        0.2229281 , 0.1864426 , 0.39064809, 0.19316241, 0.61091093,
#        0.88280845, 0.62233882, 0.25311894, 0.17993031, 0.81640447,
#        0.22537162, 0.51685714, 0.51849582, 0.60037494, 0.53262048,
#        0.01331005, 0.52409726, 0.89588471, 0.76990129, 0.1228517 ,
#        0.29587269, 0.61202358, 0.72613812, 0.46349747, 0.76911037,
#        0.19163103, 0.55786672, 0.55077816, 0.47222549, 0.79188496,
#        0.11524968, 0.6813039 , 0.36233361, 0.34420889, 0.44951875,
#        0.02694226, 0.41524769, 0.9222317 , 0.09120557, 0.31512178,
#        0.52802224, 0.32806203, 0.44891554, 0.01633442, 0.0970269 ,
#        0.69258857, 0.83594341, 0.42432199, 0.8487743 , 0.54679121,
# ...

# %%
for i in range(10):
    im_vector   = list_image[:, i]
    z = np.dot(theta,list_image)
    sigma = sigmoid(z)
    fi=np.mean(sigma)
    print(i,'=',fi)
# Out:
# 0 = 1.0
# 1 = 1.0
# 2 = 1.0
# 3 = 1.0
# 4 = 1.0
# 5 = 1.0
# 6 = 1.0
# 7 = 1.0
# 8 = 1.0
# 9 = 1.0

# %%
count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
count8 = 0
count9 = 0
for i in range(10000):
    if(list_label[i] == 0):
        count0 += 1
    elif(list_label[i] == 1):
        count1 += 1
    elif(list_label[i] == 2):
        count2 += 1
    elif(list_label[i] == 3):
        count3 += 1
    elif(list_label[i] == 4):
        count4 += 1
    elif(list_label[i] == 5):
        count5 += 1
    elif(list_label[i] == 6):
        count6 += 1
    elif(list_label[i] == 7):
        count7 += 1
    elif(list_label[i] == 8):
        count8 += 1
    elif(list_label[i] == 9):
        count9 += 1

# %%
print(count0)
print(count1)
print(count2)
print(count3)
print(count4)
print(count5)
print(count6)
print(count7)
print(count8)
print(count9)
# Out:
# 980
# 1135
# 1032
# 1010
# 982
# 892
# 958
# 1028
# 974
# 1009

# %%
image_list0 = []
image_list1 = []     
image_list2 = []
image_list3 = []
image_list4 = []
image_list5 = []
image_list6 = []
image_list7 = []
image_list8 = []
image_list9 = []
for i in range(10000):
    if(list_label[i] == 0):
        image_list0 += list_image[:,i]
    elif(list_label[i] == 1):
        image_list1 += list_image[:,i]
    elif(list_label[i] == 2):
        image_list2 += list_image[:,i]
    elif(list_label[i] == 3):
        image_list3 += list_image[:,i]
    elif(list_label[i] == 4):
        image_list4 += list_image[:,i]
    elif(list_label[i] == 5):
        image_list5 += list_image[:,i]
    elif(list_label[i] == 6):
        image_list6 += list_image[:,i]
    elif(list_label[i] == 7):
        image_list7 += list_image[:,i]
    elif(list_label[i] == 8):
        image_list8 += list_image[:,i]
    elif(list_label[i] == 9):
        image_list9 += list_image[:,i]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-fe7b5ceea43d> in <module>
#      25         image_list6 += list_image[:,i]
#      26     elif(list_label[i] == 7):
# ---> 27         image_list7 += list_image[:,i]
#      28     elif(list_label[i] == 8):
#      29         image_list8 += list_image[:,i]
#
# ValueError: operands could not be broadcast together with shapes (0,) (784,)
